# %% [markdown]
# # Basic Text Mining Function
#
# Based on **Stats Wire** video: https://www.youtube.com/watch?v=KyHlhbVk95U&list=PLBSCvBlTOLa_wS8iy84DfyizdSs7ps7L5&index=2

# %%
text1 = """To be, or not to be: that is the question:
Whether tis nobler in the mind to suffer
The slings and arrows of outrageous fortune,
Or to take arms against a sea of troubles,
And by opposing end them? To die: to sleep; 
No more; and by a sleep to say we end
The heart-ache and the thousand natural shocks
That flesh is heir to, 'tis a consummation
Devoutly to be wish'd. To die, to sleep; 
To sleep: perchance to dream: ay, there's the rub; 
For in that sleep of death what dreams may come
When we have shuffled off this mortal coil,
Must give us pause: there's the respect
That makes calamity of so long life; 
For who would bear the whips and scorns of time,
The oppressor's wrong, the proud man's contumely,
The pangs of despised love, the law's delay,
The insolence of office and the spurns
That patient merit of the unworthy takes,
When he himself might his quietus make
With a bare bodkin? who would fardels bear,
To grunt and sweat under a weary life,
But that the dread of something after death,
The undiscover'd country from whose bourn
No traveller returns, puzzles the will
And makes us rather bear those ills we have
Than fly to others that we know not of? 
Thus conscience does make cowards of us all; 
And thus the native hue of resolution
Is sicklied o'er with the pale cast of thought,
And enterprises of great pith and moment
With this regard their currents turn awry,
And lose the name of action. -Soft you now! 
The fair Ophelia! Nymph, in thy orisons
Be all my sins remember'd."""

# %%
# total len of characters in string
len(text1)
# Out:
# 1494

# %%
# replace new lines with spaces and then splitting text by spaces
text2 = text1.replace('\n',' ').split(' ')
print(text2)
# Out:
# ['To', 'be,', 'or', 'not', 'to', 'be:', 'that', 'is', 'the', 'question:', 'Whether', 'tis', 'nobler', 'in', 'the', 'mind', 'to', 'suffer', 'The', 'slings', 'and', 'arrows', 'of', 'outrageous', 'fortune,', 'Or', 'to', 'take', 'arms', 'against', 'a', 'sea', 'of', 'troubles,', 'And', 'by', 'opposing', 'end', 'them?', 'To', 'die:', 'to', 'sleep;', '', 'No', 'more;', 'and', 'by', 'a', 'sleep', 'to', 'say', 'we', 'end', 'The', 'heart-ache', 'and', 'the', 'thousand', 'natural', 'shocks', 'That', 'flesh', 'is', 'heir', 'to,', "'tis", 'a', 'consummation', 'Devoutly', 'to', 'be', "wish'd.", 'To', 'die,', 'to', 'sleep;', '', 'To', 'sleep:', 'perchance', 'to', 'dream:', 'ay,', "there's", 'the', 'rub;', '', 'For', 'in', 'that', 'sleep', 'of', 'death', 'what', 'dreams', 'may', 'come', 'When', 'we', 'have', 'shuffled', 'off', 'this', 'mortal', 'coil,', 'Must', 'give', 'us', 'pause:', "there's", 'the', 'respect', 'That', 'makes', 'calamity', 'of', 'so', 'long', 'life;', '', 'For', 'who', 'would', 'b
# ...

# %%
# number of words inside of text2
print(len(text2))
# Out:
# 283

# %%
# words with more than 10 characters
[w for w in text2 if len(w) > 10]
# Out:
# ['consummation', "oppressor's", "undiscover'd", 'enterprises', "remember'd."]

# %%
# words with less than 3 characters
[w for w in text2 if len(w) < 3]
# Out:
# ['To',
#  'or',
#  'to',
#  'is',
#  'in',
#  'to',
#  'of',
#  'Or',
#  'to',
#  'a',
#  'of',
#  'by',
#  'To',
#  'to',
#  '',
#  'No',
#  'by',
#  'a',
#  'to',
#  'we',
#  'is',
#  'a',
#  'to',
#  'be',
#  'To',
#  'to',
#  '',
#  'To',
#  'to',
#  '',
#  'in',
#  'of',
#  'we',
#  'us',
#  'of',
#  'so',
#  '',
#  'of',
#  'of',
#  'of',
#  'of',
#  'he',
#  'a',
#  'To',
#  'a',
#  'of',
#  'No',
#  'us',
#  'we',
#  'to',
#  'we',
#  '',
#  'of',
#  'us',
#  '',
#  'of',
#  'Is',
#  'of',
#  'of',
#  'of',
#  '',
#  'in',
#  'Be',
#  'my']

# %%
# words starting with capital letter
[w for w in text2 if w.istitle()]
# Out:
# ['To',
#  'Whether',
#  'The',
#  'Or',
#  'And',
#  'To',
#  'No',
#  'The',
#  'That',
#  'Devoutly',
#  'To',
#  'To',
#  'For',
#  'When',
#  'Must',
#  'That',
#  'For',
#  'The',
#  'The',
#  'The',
#  'That',
#  'When',
#  'With',
#  'To',
#  'But',
#  'The',
#  'No',
#  'And',
#  'Than',
#  'Thus',
#  'And',
#  'Is',
#  'And',
#  'With',
#  'And',
#  '-Soft',
#  'The',
#  'Ophelia!',
#  'Nymph,',
#  'Be']

# %%
# words ending with specific string
[w for w in text2 if w.endswith("a")]
# Out:
# ['a', 'sea', 'a', 'a', 'a', 'a']

# %%
text3 = "Basic text mining function Basic text mining function test text"
text4 = text3.split(' ')
print(text4)
# collection of unique elements
set(text4)
# Out:
# ['Basic', 'text', 'mining', 'function', 'Basic', 'text', 'mining', 'function', 'test', 'text']
# {'Basic', 'function', 'mining', 'test', 'text'}

# %%
# lower() all the characters in lowercase, upper() all the characters in uppercase
[w.lower() for w in text4]
# Out:
# ['basic',
#  'text',
#  'mining',
#  'function',
#  'basic',
#  'text',
#  'mining',
#  'function',
#  'test',
#  'text']

# %%
# listing each letter from text1
list(text1)
# Out:
# ['T',
#  'o',
#  ' ',
#  'b',
#  'e',
#  ',',
#  ' ',
#  'o',
#  'r',
#  ' ',
#  'n',
#  'o',
#  't',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'b',
#  'e',
#  ':',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'i',
#  's',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'q',
#  'u',
#  'e',
#  's',
#  't',
#  'i',
#  'o',
#  'n',
#  ':',
#  '\n',
#  'W',
#  'h',
#  'e',
#  't',
#  'h',
#  'e',
#  'r',
#  ' ',
#  't',
#  'i',
#  's',
#  ' ',
#  'n',
#  'o',
#  'b',
#  'l',
#  'e',
#  'r',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'm',
#  'i',
#  'n',
#  'd',
#  ' ',
#  't',
#  'o',
#  ' ',
#  's',
#  'u',
#  'f',
#  'f',
#  'e',
#  'r',
#  '\n',
#  'T',
#  'h',
#  'e',
#  ' ',
#  's',
#  'l',
#  'i',
#  'n',
#  'g',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'a',
#  'r',
#  'r',
#  'o',
#  'w',
#  's',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'o',
#  'u',
#  't',
#  'r',
#  'a',
#  'g',
#  'e',
#  'o',
#  'u',
#  's',
#  ' ',
#  'f',
#  'o',
#  'r',
#  't',
# ...
